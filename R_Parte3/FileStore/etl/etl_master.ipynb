# %%
#Pipeline master

dbutils.notebook.run("ingestion", 0)  # Ejecuta la capa Bronze
dbutils.notebook.run("transformations", 0)  # Ejecuta la capa Silver
dbutils.notebook.run("final", 0)  # Ejecuta la capa Gold
